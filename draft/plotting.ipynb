# %%
library(ggplot2)
library(dplyr)

# %%
df <- read.csv('MoHi_cleaned.csv')

# %%
head(df)
# Out:
#   restaurant      address                               latitude longitude
# 1 Zannys          975 Columbus Ave, New York, NY 10025  40.80031 -73.96168
# 2 Roasted Masala  914 Columbus Ave, New York, NY 10025  40.79856 -73.96377
# 3 Elsa            903 Columbus Ave, New York, NY 10025  40.79801 -73.96353
# 4 Uncle Luoyang   928 Amsterdam Ave, New York, NY 10025 40.80023 -73.96626
# 5 The Ellington   936 Amsterdam Ave, New York, NY 10025 40.80066 -73.96584
# 6 La Toulousianne 942 Amsterdam Ave, New York, NY 10025 40.80088 -73.96568
#   status tables booth ppp                           loan        jobs
# 1 Closed 0      0     $0-$150k, 0 jobs created      $0-$150k     0
# 2 Closed 0      0     $0-$150k, 0 jobs created      $0-$150k     0
# 3 Closed 0      0     $0-$150k, 0 jobs created      $0-$150k     0
# 4 Closed 0      0     $0-$150k, 0 jobs created      $0-$150k     0
# 5 Closed 0      0     $150k-$350k, 18 jobs retained $150k-$350k 18
# ...

# %%
# need to limit the 0-150k, too many in that group
ggplot(df, aes(x=status, fill=loan)) +
    geom_dotplot(binwidth=0.045, stackgroups=TRUE) 
ggsave('plots/loan_status.png')
# Out:
# geom_dotplot called with stackgroups=TRUE and method="dotdensity". You probably want to set binpositions="all"
# Saving 7 x 7 in image
# plot without title

# %%
loanjobs = read.csv('loan_jobs.csv')
ggplot(loanjobs, aes(x=loan, y=jobs)) + 
  geom_point()
ggsave('plots/loan_jobs.png')
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
ggplot(df, aes(x=loan, y=tables)) + 
  geom_point()
ggsave('plots/loan_save.png')
# Out:
# Saving 7 x 7 in image
# plot without title
